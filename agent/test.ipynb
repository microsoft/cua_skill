# %%
import inspect  

# import your action 
# import action.your_action as module
import action.powerpoint_action as module  
 
classes = [  
    obj  
    for name, obj in inspect.getmembers(module, inspect.isclass)  
    if obj.__module__ == module.__name__  
]  
 
for cls in classes:  
    try:  
        instance = cls()  
        print(instance.arguments)
        # print(instance)  
    except Exception as e:  
        print(f"Can't init {cls.__name__}: {e}, Please check the implementation!")
# Out:
# {'animation_name': None}
# {'slide_layout': None}
# {'transition_name': None}
# {}
# {'slide_layout': None}
# {}
# {'template_name': None}
# {'copilot_instruction': None}
# {'slide_index': None}
# {}
# {'column_index': None}
# {'row_index': None}
# {}
# {'filename': None}
# {'slide_index': None}
# {'slide_index': None}
# {'bullet_style': None}
# {'image_path': None}
# {'numbering_style': None}
# {'shape_type': None, 'shape_position': None}
# {'rows': 0, 'columns': 0}
# {'row_index': 0, 'column_index': 0, 'text': }
# {'column_index': 0}
# {'row_index': 0}
# {'text': None, 'textbox_position': None}
# {'application_name': PowerPoint}
# {'filename': None}
# {}
# {}
# {'filename': None}
# {}
# {}
# {'old_text': None, 'new_text': None}
# {'filename': None}
# {'filename': None}
# {'text': None}
# {'alignment_option': Center}
# {'case_option': sentence case}
# {'spacing_option': Normal}
# {'font_color': None}
# {'font_family': None}
# {'font_size': None}
# {'highlight': None}
# ...
